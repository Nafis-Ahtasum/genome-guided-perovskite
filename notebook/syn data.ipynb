# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("/content/drive/MyDrive/Colab-dataset/A2-B(I)-B'(III)-X6.csv")

# %%
dataset.head()
# Out:
#   material_id  formula   A  B1  B3  X  band_gap  formation_energy_per_atom  \
# 0    mp-15254  Li3AlF6  Li  Li  Al  F    7.7827                  -3.487262
# 1  mp-1111291  Li3AlF6  Li  Li  Al  F    6.5056                  -3.306112
# 2   mp-556020  Li3AlF6  Li  Li  Al  F    8.0807                  -3.485647
# 3    mp-15558  Li3GaF6  Li  Li  Ga  F    6.3640                  -3.094404
# 4  mp-1111076  Li3GaF6  Li  Li  Ga  F    5.7707                  -2.900952
#
#    e_above_hull  A-X Bond Length  B-X Bond Length  B'-X Bond Length
# 0      0.000000         3.000049         3.000049          2.966722
# 1      0.181150         2.254274         2.254274          1.781863
# 2      0.001615         3.000100         3.000100          2.906619
# 3      0.000000         3.002316         3.002316          3.007779
# 4      0.193452         2.339499         2.339499          1.895814

# %%
dataset['n_formula'] = dataset.apply(lambda row: f"{row['A']}2{row['B1']}{row['B3']}{row['X']}6", axis=1)
dataset.head()
# Out:
#   material_id  formula   A  B1  B3  X  band_gap  formation_energy_per_atom  \
# 0    mp-15254  Li3AlF6  Li  Li  Al  F    7.7827                  -3.487262
# 1  mp-1111291  Li3AlF6  Li  Li  Al  F    6.5056                  -3.306112
# 2   mp-556020  Li3AlF6  Li  Li  Al  F    8.0807                  -3.485647
# 3    mp-15558  Li3GaF6  Li  Li  Ga  F    6.3640                  -3.094404
# 4  mp-1111076  Li3GaF6  Li  Li  Ga  F    5.7707                  -2.900952
#
#    e_above_hull  A-X Bond Length  B-X Bond Length  B'-X Bond Length  n_formula
# 0      0.000000         3.000049         3.000049          2.966722  Li2LiAlF6
# 1      0.181150         2.254274         2.254274          1.781863  Li2LiAlF6
# 2      0.001615         3.000100         3.000100          2.906619  Li2LiAlF6
# 3      0.000000         3.002316         3.002316          3.007779  Li2LiGaF6
# 4      0.193452         2.339499         2.339499          1.895814  Li2LiGaF6

# %%
monovalent_cations_A = ["Li", "Na", "K", "Rb", "Cs", "Cu", "Au", "Ag"]
monovalent_cations_B1 = ["Li", "Na", "K", "Rb", "Cs", "Cu", "Au", "Ag"]
divalent_cations_B2 = ["Pb", "Sn", "Ge", "Be", "Mg", "Ca", "Sr", "Ba", "Mn", "Fe", "Co", "Ni", "Cu", "Zn", "Pd", "Ir", "Pt", "Te", "Cd"]
trivalent_cations_B3 = ["Al", "Ga", "In", "Sb", "Bi", "Au", "Sc", "Y"]
halide_anions_X = ["F", "Cl", "Br", "I"]

# %%
class CombinationGenerator:
    def __init__(self, monovalent_cations_A, b1_cations, b3_cations, halide_anions_X):

        self.monovalent_cations_A = monovalent_cations_A
        self.b1_cations = b1_cations
        self.b3_cations = b3_cations
        self.halide_anions_X = halide_anions_X

    def generate_combinations(self) -> list[dict]:

        combinations = []
        for a in self.monovalent_cations_A:
            for b1 in self.b1_cations:
                for b3 in self.b3_cations:
                    for x in self.halide_anions_X:
                        combinations.append({
                            'formula': f"{a}2{b1}{b3}{x}6",
                            'A': a,
                            'B1': b1,
                            'B3': b3,
                            'X': x
                        })
        return combinations

# %%
combination_generator_b1b3 = CombinationGenerator(
        monovalent_cations_A,
        monovalent_cations_B1,
        trivalent_cations_B3,
        halide_anions_X
    )
ab1b3x6_combinations = combination_generator_b1b3.generate_combinations()

# %%
ab1b3x6_combinations_df = pd.DataFrame(ab1b3x6_combinations)
ab1b3x6_combinations_df.head()
# Out:
#       formula   A  B1  B3   X
# 0   Li2LiAlF6  Li  Li  Al   F
# 1  Li2LiAlCl6  Li  Li  Al  Cl
# 2  Li2LiAlBr6  Li  Li  Al  Br
# 3   Li2LiAlI6  Li  Li  Al   I
# 4   Li2LiGaF6  Li  Li  Ga   F

# %%
ab1b3x6_combinations_df = ab1b3x6_combinations_df[~ab1b3x6_combinations_df['formula'].isin(dataset['n_formula'])].reset_index(drop=True)

# %%
syn_b3_df = ab1b3x6_combinations_df
syn_b3_df.head()
# Out:
#       formula   A  B1  B3   X
# 0  Li2LiAlCl6  Li  Li  Al  Cl
# 1  Li2LiAlBr6  Li  Li  Al  Br
# 2   Li2LiAlI6  Li  Li  Al   I
# 3  Li2LiGaCl6  Li  Li  Ga  Cl
# 4  Li2LiGaBr6  Li  Li  Ga  Br

# %%
dataset = pd.read_csv("/content/drive/MyDrive/Colab-dataset/A2-B(II)-B'(II)-X6.csv")

# %%
dataset['n_formula'] = dataset.apply(lambda row: f"{row['A']}2{row['B1']}{row['B3']}{row['X']}6", axis=1)
dataset.head()
# Out:
#   material_id  formula   A  B1  B3   X  band_gap  formation_energy_per_atom  \
# 0   mp-998230  LiSnCl3  Li  Sn  Sn  Cl    0.0003                  -1.677136
# 1   mp-998591  LiSnCl3  Li  Sn  Sn  Cl    3.4801                  -1.687654
# 2  mp-3346453  LiMgCl3  Li  Mg  Mg  Cl    5.5482                  -2.045754
# 3  mp-1017626   LiCaF3  Li  Ca  Ca   F    6.5153                  -3.621491
# 4    mp-10250   BaLiF3  Li  Ba  Ba   F    6.5643                  -3.741441
#
#    e_above_hull  A-X Bond Length  B-X Bond Length  B'-X Bond Length  \
# 0      0.020804         2.549029         3.377626          3.377626
# 1      0.010285         2.577285         2.943450          2.943450
# 2      0.014322         2.588155         2.501234          2.501234
# 3      0.187439         1.880622         2.659601          2.659601
# 4      0.021903         1.994291         2.820353          2.820353
#
#     n_formula
# 0  Li2SnSnCl6
# 1  Li2SnSnCl6
# 2  Li2MgMgCl6
# 3   Li2CaCaF6
# 4   Li2BaBaF6

# %%
combination_generator_b2b2 = CombinationGenerator(
        monovalent_cations_A,
        divalent_cations_B2,
        divalent_cations_B2,
        halide_anions_X
    )
ab2b2x6_combinations = combination_generator_b2b2.generate_combinations()

# %%
syn_b2_df = pd.DataFrame(ab2b2x6_combinations)
syn_b2_df.head()
# Out:
#       formula   A  B1  B3   X
# 0   Li2PbPbF6  Li  Pb  Pb   F
# 1  Li2PbPbCl6  Li  Pb  Pb  Cl
# 2  Li2PbPbBr6  Li  Pb  Pb  Br
# 3   Li2PbPbI6  Li  Pb  Pb   I
# 4   Li2PbSnF6  Li  Pb  Sn   F

# %%
syn_b2_df =  syn_b2_df[~syn_b2_df['formula'].isin(dataset['n_formula'])].reset_index(drop=True)

# %%
# @title Assigning A+ elements to variables
element_data = {
    "Li": {
        "Ionic radius (pm)": 76,
        "Ionization energy (kJ/mol)": 520.2,
        "Valence electron number": 1,
        "Polarizability (a.u.)": 164.1, # Atomic polarizability of neutral Li (a.u.) - A more common value for neutral Li. The provided value seems to be for Li+ ion.
        "Atom formation enthalpy (kJ/mol)": 161, # Standard enthalpy of atomization for Li
        "Atomic number": 3
    },
    "Na": {
        "Ionic radius (pm)": 102, # Na+
        "Ionization energy (kJ/mol)": 495.8,
        "Valence electron number": 1,
        "Polarizability (a.u.)": 162.88, # Atomic polarizability of neutral Na (a.u.)
        "Atom formation enthalpy (kJ/mol)": 108.4, # Standard enthalpy of atomization for Na
        "Atomic number": 11
    },
    "K": {
        "Ionic radius (pm)": 138, # K+
        "Ionization energy (kJ/mol)": 418.8,
        "Valence electron number": 1,
        "Polarizability (a.u.)": 290.1, # Atomic polarizability of neutral K (a.u.) - Based on trends and comparisons with other alkali metals. Specific search results were less direct for a single value.
        "Atom formation enthalpy (kJ/mol)": 89, # Standard enthalpy of atomization for K
        "Atomic number": 19
    },
    "Rb": {
        "Ionic radius (pm)": 152, # Rb+
        "Ionization energy (kJ/mol)": 403.0,
        "Valence electron number": 1,
        "Polarizability (a.u.)": 319.2, # Atomic polarizability of neutral Rb (a.u.) - Based on trends and comparisons with other alkali metals. Specific search results were less direct for a single value.
        "Atom formation enthalpy (kJ/mol)": 81, # Standard enthalpy of atomization for Rb
        "Atomic number": 37
    },
    "Cs": {
        "Ionic radius (pm)": 167, # Cs+
        "Ionization energy (kJ/mol)": 375.7,
        "Valence electron number": 1,
        "Polarizability (a.u.)": 400, # Atomic polarizability of neutral Cs (a.u.) - Approximate value found in research
        "Atom formation enthalpy (kJ/mol)": 76, # Standard enthalpy of atomization for Cs
        "Atomic number": 55
    },
    "Cu": {
        "Ionic radius (pm)": 73, # Cu+
        "Ionization energy (kJ/mol)": 745.5,
        "Valence electron number": 1,
        "Polarizability (a.u.)": 48.12, # Static dipole polarizability of neutral Cu (a.u.)
        "Atom formation enthalpy (kJ/mol)": 338, # Standard enthalpy of atomization for Cu
        "Atomic number": 29
    },
    "Au": {
        "Ionic radius (pm)": 137, # Au3+ or Au+ depending on source
        "Ionization energy (kJ/mol)": 890.1,
        "Valence electron number": 1,
        "Polarizability (a.u.)": 36.68, # Static dipole polarizability of neutral Au (a.u.)
        "Atom formation enthalpy (kJ/mol)": 326, # Standard enthalpy of atomization for Au
        "Atomic number": 79
    },
    "Ag": {
        "Ionic radius (pm)": 126, # Ag+
        "Ionization energy (kJ/mol)": 731.0,
        "Valence electron number": 1,
        "Polarizability (a.u.)": 50.97, # Static dipole polarizability of neutral Ag (a.u.)
        "Atom formation enthalpy (kJ/mol)": 285, # Standard enthalpy of atomization for Ag
        "Atomic number": 47
    }
}

# %%
# @title Assigning B2+ elements to variables
element_data_2 = {
    "Pb": {
        "Ionic radius (pm)": 119,
        "Electronegativity (Pauling)": 2.33,
        "Valence electron number": 2,
        "Polarizability (a.u.)": 48.0, # Static dipole polarizability of neutral Pb (a.u.) - Value from literature
        "Atom formation enthalpy (kJ/mol)": 195, # Standard enthalpy of atomization for Pb (from WebElements/Wired Chemist)
        "Atomic number": 82
    },
    "Sn": {
        "Ionic radius (pm)": 118, # Sn2+
        "Electronegativity (Pauling)": 1.96,
        "Valence electron number": 4,
        "Polarizability (a.u.)": 50.0, # Static dipole polarizability of neutral Sn (a.u.) - Value from literature/tables
        "Atom formation enthalpy (kJ/mol)": 302, # Standard enthalpy of atomization for Sn (from WebElements)
        "Atomic number": 50
    },
    "Ge": {
        "Ionic radius (pm)": 73, # Ge4+
        "Electronegativity (Pauling)": 2.01,
        "Valence electron number": 4,
        "Polarizability (a.u.)": 37.5, # Static dipole polarizability of neutral Ge (a.u.) - Value from literature/tables
        "Atom formation enthalpy (kJ/mol)": 377, # Standard enthalpy of atomization for Ge (from WebElements)
        "Atomic number": 32
    },
    "Be": {
        "Ionic radius (pm)": 45, # Be2+ (Source: Wired Chemist)
        "Electronegativity (Pauling)": 1.57, # (Commonly cited value)
        "Valence electron number": 2,
        "Polarizability (a.u.)": 37.7, # Static dipole polarizability of neutral Be (a.u.) - From Schwerdtfeger & Nagle tables (e.g., 2018, 2020, 2023 updates)
        "Atom formation enthalpy (kJ/mol)": 324, # Standard enthalpy of atomization for Be (from WebElements/Wired Chemist)
        "Atomic number": 4
    },
    "Mg": {
        "Ionic radius (pm)": 72, # Mg2+
        "Electronegativity (Pauling)": 1.31,
        "Valence electron number": 7,
        "Polarizability (a.u.)": 71.2, # Static dipole polarizability of neutral Mg (a.u.) - Value from literature/tables (e.g., Schwerdtfeger & Nagle)
        "Atom formation enthalpy (kJ/mol)": 146, # Standard enthalpy of atomization for Mg (from WebElements)
        "Atomic number": 12
    },
    "Ca": {
        "Ionic radius (pm)": 100, # Ca2+
        "Electronegativity (Pauling)": 1.00,
        "Valence electron number": 2,
        "Polarizability (a.u.)": 161, # Static dipole polarizability of neutral Ca (a.u.) - Value from literature/tables (e.g., Schwerdtfeger & Nagle)
        "Atom formation enthalpy (kJ/mol)": 178, # Standard enthalpy of atomization for Ca (from WebElements)
        "Atomic number": 20
    },
    "Sr": {
        "Ionic radius (pm)": 118, # Sr2+
        "Electronegativity (Pauling)": 0.95,
        "Valence electron number": 2,
        "Polarizability (a.u.)": 197, # Static dipole polarizability of neutral Sr (a.u.) - Value from literature/tables (e.g., Schwerdtfeger & Nagle)
        "Atom formation enthalpy (kJ/mol)": 164, # Standard enthalpy of atomization for Sr (from WebElements)
        "Atomic number": 38
    },
    "Ba": {
        "Ionic radius (pm)": 135, # Ba2+
        "Electronegativity (Pauling)": 0.89,
        "Valence electron number": 2,
        "Polarizability (a.u.)": 272, # Static dipole polarizability of neutral Ba (a.u.) - Value from literature/tables (e.g., Schwerdtfeger & Nagle)
        "Atom formation enthalpy (kJ/mol)": 182, # Standard enthalpy of atomization for Ba (from WebElements)
        "Atomic number": 56
    },
    "Mn": {
        "Ionic radius (pm)": 67, # Mn2+ (common)
        "Electronegativity (Pauling)": 1.55,
        "Valence electron number": 2,
        "Polarizability (a.u.)": 60.8, # Static dipole polarizability of neutral Mn (a.u.) - Value from literature/tables
        "Atom formation enthalpy (kJ/mol)": 281, # Standard enthalpy of atomization for Mn (from WebElements)
        "Atomic number": 25
    },
    "Fe": {
        "Ionic radius (pm)": 70, # Fe2+ (common) or 60 (Fe3+)
        "Electronegativity (Pauling)": 1.83,
        "Valence electron number": 8,
        "Polarizability (a.u.)": 56.0, # Static dipole polarizability of neutral Fe (a.u.) - Value from literature/tables
        "Atom formation enthalpy (kJ/mol)": 415, # Standard enthalpy of atomization for Fe (from WebElements)
        "Atomic number": 26
    },
    "Co": {
        "Ionic radius (pm)": 65, # Co2+ (common) or 61 (Co3+)
        "Electronegativity (Pauling)": 1.88,
        "Valence electron number": 9,
        "Polarizability (a.u.)": 49.6, # Static dipole polarizability of neutral Co (a.u.) - Value from literature/tables
        "Atom formation enthalpy (kJ/mol)": 426, # Standard enthalpy of atomization for Co (from WebElements)
        "Atomic number": 27
    },
    "Ni": {
        "Ionic radius (pm)": 69, # Ni2+
        "Electronegativity (Pauling)": 1.91,
        "Valence electron number": 10,
        "Polarizability (a.u.)": 43.0, # Static dipole polarizability of neutral Ni (a.u.) - Value from literature/tables
        "Atom formation enthalpy (kJ/mol)": 431, # Standard enthalpy of atomization for Ni (from WebElements)
        "Atomic number": 28
    },
    "Cu": {
        "Ionic radius (pm)": 73, # Cu2+ (common oxidation state, value from WebElements/Filo)
        "Electronegativity (Pauling)": 1.90, # (From WebElements)
        "Valence electron number": 1, # Common oxidation states +1, +2
        "Polarizability (a.u.)": 46.91, # Static dipole polarizability of neutral Cu (a.u.) (Source: ACS Publications)
        "Atom formation enthalpy (kJ/mol)": 338, # Standard enthalpy of atomization for Cu (from WebElements/Vedantu)
        "Atomic number": 29
    },
    "Zn": {
        "Ionic radius (pm)": 74, # Zn2+
        "Electronegativity (Pauling)": 1.65,
        "Valence electron number": 2,
        "Polarizability (a.u.)": 37.95, # Static dipole polarizability of neutral Zn (a.u.) - Value from literature/tables (e.g., Schwerdtfeger & Nagle)
        "Atom formation enthalpy (kJ/mol)": 131, # Standard enthalpy of atomization for Zn (from WebElements/Wired Chemist)
        "Atomic number": 30
    },
    "Pd": {
        "Ionic radius (pm)": 86, # Pd2+
        "Electronegativity (Pauling)": 2.20,
        "Valence electron number": 10,
        "Polarizability (a.u.)": 26.14, # Static dipole polarizability of neutral Pd (a.u.) - Value from literature (e.g., Jerabek & Schwerdtfeger)
        "Atom formation enthalpy (kJ/mol)": 377, # Standard enthalpy of atomization for Pd (from WebElements)
        "Atomic number": 46
    },
    "Ir": {
        "Ionic radius (pm)": 62.5, # Ir3+
        "Electronegativity (Pauling)": 2.20,
        "Valence electron number": 9, # Common oxidation states include +3, +4
        "Polarizability (a.u.)": 47.0, # Static dipole polarizability of neutral Ir (a.u.) - Value from literature/tables
        "Atom formation enthalpy (kJ/mol)": 671, # Standard enthalpy of atomization for Ir (from WebElements)
        "Atomic number": 77
    },
    "Pt": {
        "Ionic radius (pm)": 80, # Pt2+ (common) or 77 (Pt4+)
        "Electronegativity (Pauling)": 2.28,
        "Valence electron number": 10,
        "Polarizability (a.u.)": 48.0, # Static dipole polarizability of neutral Pt (a.u.) - Value from literature/tables
        "Atom formation enthalpy (kJ/mol)": 561, # Standard enthalpy of atomization for Pt (from literature/tables)
        "Atomic number": 78
    },
    "Te": {
        "Ionic radius (pm)": 135, # Te2-
        "Electronegativity (Pauling)": 2.1,
        "Valence electron number": 6,
        "Polarizability (a.u.)": 37.0, # Static dipole polarizability of neutral Te (a.u.) - Value from literature/tables
        "Atom formation enthalpy (kJ/mol)": 197, # Standard enthalpy of atomization for Te (from WebElements)
        "Atomic number": 52
    },
    "Cd": {
        "Ionic radius (pm)": 95, # Cd2+
        "Electronegativity (Pauling)": 1.69,
        "Valence electron number": 2,
        "Polarizability (a.u.)": 49.65, # Static dipole polarizability of neutral Cd (a.u.) - Experimental value from literature
        "Atom formation enthalpy (kJ/mol)": 112, # Standard enthalpy of atomization for Cd (from WebElements)
        "Atomic number": 48
    }
}

# %%
# @title Assigning B3+ elements to variables
element_data_3 = {
    "Al": {
        "Ionic radius (pm)": 53,  # Al3+
        "Electronegativity (Pauling)": 1.61,
        "Valence electron number": 3,
        "Polarizability (a.u.)": 55.0, # Static dipole polarizability of neutral Al (a.u.) - Value from literature/tables
        "Atom formation enthalpy (kJ/mol)": 326, # Standard enthalpy of atomization for Al (from WebElements)
        "Atomic number": 13
    },
    "Ga": {
        "Ionic radius (pm)": 76,  # Ga3+
        "Electronegativity (Pauling)": 1.81,
        "Valence electron number": 3,
        "Polarizability (a.u.)": 67.0, # Static dipole polarizability of neutral Ga (a.u.) - Value from literature/tables
        "Atom formation enthalpy (kJ/mol)": 277, # Standard enthalpy of atomization for Ga (from WebElements)
        "Atomic number": 31
    },
    "In": {
        "Ionic radius (pm)": 94,  # In3+
        "Electronegativity (Pauling)": 1.78,
        "Valence electron number": 3,
        "Polarizability (a.u.)": 83.0, # Static dipole polarizability of neutral In (a.u.) - Value from literature/tables
        "Atom formation enthalpy (kJ/mol)": 243, # Standard enthalpy of atomization for In (from WebElements/Wired Chemist)
        "Atomic number": 49
    },
    "Sb": {
        "Ionic radius (pm)": 76,  # Sb3+
        "Electronegativity (Pauling)": 2.05,
        "Valence electron number": 5, # Can vary
        "Polarizability (a.u.)": 55.0, # Static dipole polarizability of neutral Sb (a.u.) - Value from literature/tables
        "Atom formation enthalpy (kJ/mol)": 262, # Standard enthalpy of atomization for Sb (from WebElements)
        "Atomic number": 51
    },
    "Bi": {
        "Ionic radius (pm)": 103, # Bi3+
        "Electronegativity (Pauling)": 2.02,
        "Valence electron number": 5, # Can vary
        "Polarizability (a.u.)": 62.0, # Static dipole polarizability of neutral Bi (a.u.) - Value from literature/tables
        "Atom formation enthalpy (kJ/mol)": 207, # Standard enthalpy of atomization for Bi (from WebElements)
        "Atomic number": 83
    },
    "Au": {
        "Ionic radius (pm)": 137,
        "Electronegativity (Pauling)": 2.54,
        "Valence electron number": 1, # Can vary, commonly considered 1 for reactivity
        "Polarizability (a.u.)": 36.68, # Static dipole polarizability of neutral Au (a.u.) - Value from literature/tables
        "Atom formation enthalpy (kJ/mol)": 366, # Standard enthalpy of atomization for Au (from literature/Wired Chemist)
        "Atomic number": 79
    },
    "Sc": {
        "Ionic radius (pm)": 89,  # Sc3+
        "Electronegativity (Pauling)": 1.36,
        "Valence electron number": 3,
        "Polarizability (a.u.)": 103.0, # Static dipole polarizability of neutral Sc (a.u.) - Value from literature/tables
        "Atom formation enthalpy (kJ/mol)": 378, # Standard enthalpy of atomization for Sc (from WebElements)
        "Atomic number": 21
    },
    "Y": {
        "Ionic radius (pm)": 104, # Y3+
        "Electronegativity (Pauling)": 1.22,
        "Valence electron number": 3,
        "Polarizability (a.u.)": 137.0, # Static dipole polarizability of neutral Y (a.u.) - Value from literature/tables
        "Atom formation enthalpy (kJ/mol)": 423, # Standard enthalpy of atomization for Y (from literature/Wired Chemist)
        "Atomic number": 39
    }
}

# %%
# @title Assigning X- elements to variables
element_data_4 = {
    "F": {
        "Ionic radius (pm)": 133,  # F-
        "Electronegativity (Pauling)": 3.98,
        "Valence electron number": 7,
        "Polarizability (a.u.)": 3.74, # Static dipole polarizability of neutral F (a.u.) - Value from literature/tables (e.g., Schwerdtfeger & Nagle)
        "Atom formation enthalpy (kJ/mol)": 79.08, # Enthalpy of atomization (1/2 F2 -> F)
        "Electron affinity (kJ/mol)": -328,
        "Atomic number": 9
    },
    "Cl": {
        "Ionic radius (pm)": 181, # Cl-
        "Electronegativity (Pauling)": 3.16,
        "Valence electron number": 7,
        "Polarizability (a.u.)": 14.6, # Static dipole polarizability of neutral Cl (a.u.) - Value from literature/tables (e.g., Schwerdtfeger & Nagle)
        "Atom formation enthalpy (kJ/mol)": 121.8, # Enthalpy of atomization (1/2 Cl2 -> Cl)
        "Electron affinity (kJ/mol)": -349,
        "Atomic number": 17
    },
    "Br": {
        "Ionic radius (pm)": 196, # Br-
        "Electronegativity (Pauling)": 2.96,
        "Valence electron number": 7,
        "Polarizability (a.u.)": 21.6, # Static dipole polarizability of neutral Br (a.u.) - Value from literature/tables (e.g., Schwerdtfeger & Nagle)
        "Atom formation enthalpy (kJ/mol)": 111.7, # Enthalpy of atomization (1/2 Br2 -> Br)
        "Electron affinity (kJ/mol)": -324,
        "Atomic number": 35
    },
    "I": {
        "Ionic radius (pm)": 220, # I-
        "Electronegativity (Pauling)": 2.66,
        "Valence electron number": 7,
        "Polarizability (a.u.)": 32.9, # Static dipole polarizability of neutral I (a.u.) - Value from literature/tables (e.g., Schwerdtfeger & Nagle)
        "Atom formation enthalpy (kJ/mol)": 106.7, # Enthalpy of atomization (1/2 I2 -> I)
        "Electron affinity (kJ/mol)": -295,
        "Atomic number": 53
    }
}

# %%
# @title Bond Energy of A-X

bond_energy_A_X = {
    "Li": {
        "F": 574.9,
        "Cl": 470.7,
        "Br": 423.0,
        "I": 352
    },
    "Na": {
        "F": 481.0,
        "Cl": 410.0,
        "Br": 370.0,
        "I": 301.0
    },
    "K": {
        "F": 497.5,
        "Cl": 425.9,
        "Br": 383.0,
        "I": 331.0
    },
    "Rb": {
        "F": 494.0,
        "Cl": 448.0,
        "Br": 389.0,
        "I": 335.0
    },
    "Cs": {
        "F": 514.0,
        "Cl": 439.0,
        "Br": 397.5,
        "I": 339.0
    },
    "Cu": {
        "F": 297.0,
        "Cl": 383.0,
        "Br": 331.0,
        "I": 197.0
    },
    "Au": {
        "F": None,
        "Cl": 343,
        "Br": None,
        "I": None
    },
    "Ag": {
        "F": 354.0,
        "Cl": 341.4,
        "Br": 293.0,
        "I": 234.0
    }
}

# %%
# @title Bond Energy of B1-X
bond_energy_B1_X =bond_energy_B1_X = {
    "Pb": {
        "F": 356,
        "Cl": 301,
        "Br": 247,
        "I": 197
    },
    "Sn": {
        "F": 466.5,
        "Cl": 406,
        "Br": 326,
        "I": 234
    },
    "Ge": {
        "F": 485,
        "Cl": 431.8,
        "Br": 255,
        "I": None
    },
    "Be": {
        "F": 577,
        "Cl": 388,
        "Br": 381,
        "I": None
    },
    "Mg": {
        "F": 462,
        "Cl": 318,
        "Br": 297,
        "I": 285
    },
    "Ca": {
        "F": 527,
        "Cl": 398,
        "Br": 321,
        "I": 285
    },
    "Sr": {
        "F": 542,
        "Cl": 406,
        "Br": 332,
        "I": 263
    },
    "Ba": {
        "F": 487,
        "Cl": 444,
        "Br": 370,
        "I": 431
    },
    "Mn": {
        "F": 423,
        "Cl": 361,
        "Br": 314,
        "I": 283
    },
    "Fe": {
        "F": 394,
        "Cl": 352,
        "Br": 247,
        "I": None
    },
    "Co": {
        "F": 435,
        "Cl": 398,
        "Br": 331,
        "I": 235
    },
    "Ni": {
        "F": 435,
        "Cl": 367.9,
        "Br": 354.1,
        "I": 289
    },
    "Cu": {
        "F": 297,
        "Cl": 383,
        "Br": 331,
        "I": 197
    },
    "Zn": {
        "F": 368,
        "Cl": 229,
        "Br": 142,
        "I": 138
    },
    "Pd": {
        "F": None,
        "Cl": 238,
        "Br": None,
        "I": 253.6,
    },
    "Ir": {
        "F": None,         #uncertain
        "Cl": None,
        "Br": None,
        "I": None
    },
    "Pt": {
        "F": 435.3,       #NIST
        "Cl": 383,
        "Br": None,
        "I": None
    },
    "Te": {
        "F": 340,     #NIST 1970
        "Cl": 322,
        "Br": 297,
        "I": 193
    },
    "Cd": {
        "F": 305,
        "Cl": 206.7,
        "Br": 159,
        "I": 138
    }
}

# %%
# @title Bond Energy B3-X

bond_energy_B3_X = {
    "Al": {
        "F": 664,
        "Cl": 494,
        "Br": 439,
        "I": 368
    },
    "Ga": {
        "F": 577,
        "Cl": 481,
        "Br": 444,
        "I": 339
    },
    "In": {
        "F": 506,
        "Cl": 439,
        "Br": 418,
        "I": None
    },
    "Sb": {
        "F": 439,
        "Cl": 360,
        "Br": 314,
        "I": None
    },
    "Bi": {
        "F": 259,
        "Cl": 305,
        "Br": 267,
        "I": None
    },
    "Au": {
        "F": None,
        "Cl": 343,
        "Br": None,
        "I": None
    },
    "Sc": {
        "F": 589,
        "Cl": 318,
        "Br": 444,
        "I": None
    },
    "Y": {
        "F": 605,
        "Cl": 527,
        "Br": 485,
        "I": None
    }
}

# %%
df_b3 = syn_b3_df
df_b2 = syn_b2_df

# %%
for element, data in element_data.items():
    # Apply the changes only for specific rows
    if element in df_b2['A'].values:
      for index in df_b2[df_b2["A"] == element].index:
        df_b2.loc[index, "R-A(pm)"] = data["Ionic radius (pm)"]
        df_b2.loc[index, "I-A(kJ/mol)"] = data["Ionization energy (kJ/mol)"]
        df_b2.loc[index, "V-A"] = data["Valence electron number"]
        df_b2.loc[index, "P-A"] = data["Polarizability (a.u.)"]
        df_b2.loc[index, "E-A(kJ/mol)"] = data["Atom formation enthalpy (kJ/mol)"]
        df_b2.loc[index, "N-A"] = data["Atomic number"]

# %%
for element, data in element_data_2.items():
    # Apply the changes only for specific rows
    if element in df_b2['B1'].values:
      for index in df_b2[df_b2["B1"] == element].index:
        df_b2.loc[index, "R-B1(pm)"] = data["Ionic radius (pm)"]
        df_b2.loc[index, "X-B1(kJ/mol)"] = data["Electronegativity (Pauling)"]
        df_b2.loc[index, "V-B1"] = data["Valence electron number"]
        df_b2.loc[index, "P-B1"] = data["Polarizability (a.u.)"]
        df_b2.loc[index, "E-B1(kJ/mol)"] = data["Atom formation enthalpy (kJ/mol)"]
        df_b2.loc[index, "N-B1"] = data["Atomic number"]

# %%
for element, data in element_data_2.items():
    # Apply the changes only for specific rows
    if element in df_b2['B3'].values:
      for index in df_b2[df_b2["B3"] == element].index:
        df_b2.loc[index, "R-B3(pm)"] = data["Ionic radius (pm)"]
        df_b2.loc[index, "X-B3(kJ/mol)"] = data["Electronegativity (Pauling)"]
        df_b2.loc[index, "V-B3"] = data["Valence electron number"]
        df_b2.loc[index, "P-B3"] = data["Polarizability (a.u.)"]
        df_b2.loc[index, "E-B3(kJ/mol)"] = data["Atom formation enthalpy (kJ/mol)"]
        df_b2.loc[index, "N-B3"] = data["Atomic number"]

# %%
for element, data in element_data_4.items():
    # Apply the changes only for specific rows
    if element in df_b2['X'].values:
      for index in df_b2[df_b2["X"] == element].index:
        df_b2.loc[index, "R-X(pm)"] = data["Ionic radius (pm)"]
        df_b2.loc[index, "X-X(kJ/mol)"] = data["Electronegativity (Pauling)"]
        df_b2.loc[index, "V-X"] = data["Valence electron number"]
        df_b2.loc[index, "P-X"] = data["Polarizability (a.u.)"]
        df_b2.loc[index, "E-X(kJ/mol)"] = data["Atom formation enthalpy (kJ/mol)"]
        df_b2.loc[index, "A-X(kJ/mol)"] = data["Electron affinity (kJ/mol)"]
        df_b2.loc[index, "N-X"] = data["Atomic number"]

# %%
for element_a, data_a in bond_energy_A_X.items():
    for element_x, bond_energy in data_a.items():
        mask = (df_b2['A'] == element_a) & (df_b2['X'] == element_x)
        df_b2.loc[mask, 'BE(A-X)'] = bond_energy

# %%
for element_a, data_a in bond_energy_B1_X.items():
    for element_x, bond_energy in data_a.items():
        mask = (df_b2['B1'] == element_a) & (df_b2['X'] == element_x)
        df_b2.loc[mask, 'BE(B1-X)'] = bond_energy

# %%
for element_a, data_a in bond_energy_B1_X.items():
    for element_x, bond_energy in data_a.items():
        mask = (df_b2['B3'] == element_a) & (df_b2['X'] == element_x)
        df_b2.loc[mask, 'BE(B3-X)'] = bond_energy

# %%
df_b2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11538 entries, 0 to 11537
# Data columns (total 33 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   formula       11538 non-null  object
#  1   A             11538 non-null  object
#  2   B1            11538 non-null  object
#  3   B3            11538 non-null  object
#  4   X             11538 non-null  object
#  5   R-A(pm)       11538 non-null  float64
#  6   I-A(kJ/mol)   11538 non-null  float64
#  7   V-A           11538 non-null  float64
#  8   P-A           11538 non-null  float64
#  9   E-A(kJ/mol)   11538 non-null  float64
#  10  N-A           11538 non-null  float64
#  11  R-B1(pm)      11538 non-null  float64
#  12  X-B1(kJ/mol)  11538 non-null  float64
#  13  V-B1          11538 non-null  float64
#  14  P-B1          11538 non-null  float64
#  15  E-B1(kJ/mol)  11538 non-null  float64
#  16  N-B1          11538 non-null  float64
# ...

# %%
for element, data in element_data.items():
    # Apply the changes only for specific rows
    if element in df_b3['A'].values:
      for index in df_b3[df_b3["A"] == element].index:
        df_b3.loc[index, "R-A(pm)"] = data["Ionic radius (pm)"]
        df_b3.loc[index, "I-A(kJ/mol)"] = data["Ionization energy (kJ/mol)"]
        df_b3.loc[index, "V-A"] = data["Valence electron number"]
        df_b3.loc[index, "P-A"] = data["Polarizability (a.u.)"]
        df_b3.loc[index, "E-A(kJ/mol)"] = data["Atom formation enthalpy (kJ/mol)"]
        df_b3.loc[index, "N-A"] = data["Atomic number"]

# %%
for element, data in element_data.items():
    # Apply the changes only for specific rows
    if element in df_b3['B1'].values:
      for index in df_b3[df_b3["B1"] == element].index:
        df_b3.loc[index, "R-B1(pm)"] = data["Ionic radius (pm)"]
        # Putting Ionization value as Electronegetivity
        df_b3.loc[index, "X-B1(kJ/mol)"] = data["Ionization energy (kJ/mol)"]
        df_b3.loc[index, "V-B1"] = data["Valence electron number"]
        df_b3.loc[index, "P-B1"] = data["Polarizability (a.u.)"]
        df_b3.loc[index, "E-B1(kJ/mol)"] = data["Atom formation enthalpy (kJ/mol)"]
        df_b3.loc[index, "N-B1"] = data["Atomic number"]

# %%
for element, data in element_data_3.items():
    # Apply the changes only for specific rows
    if element in df_b3['B3'].values:
      for index in df_b3[df_b3["B3"] == element].index:
        df_b3.loc[index, "R-B3(pm)"] = data["Ionic radius (pm)"]
        df_b3.loc[index, "X-B3(kJ/mol)"] = data["Electronegativity (Pauling)"]
        df_b3.loc[index, "V-B3"] = data["Valence electron number"]
        df_b3.loc[index, "P-B3"] = data["Polarizability (a.u.)"]
        df_b3.loc[index, "E-B3(kJ/mol)"] = data["Atom formation enthalpy (kJ/mol)"]
        df_b3.loc[index, "N-B3"] = data["Atomic number"]

# %%
for element, data in element_data_4.items():
    # Apply the changes only for specific rows
    if element in df_b3['X'].values:
      for index in df_b3[df_b3["X"] == element].index:
        df_b3.loc[index, "R-X(pm)"] = data["Ionic radius (pm)"]
        df_b3.loc[index, "X-X(kJ/mol)"] = data["Electronegativity (Pauling)"]
        df_b3.loc[index, "V-X"] = data["Valence electron number"]
        df_b3.loc[index, "P-X"] = data["Polarizability (a.u.)"]
        df_b3.loc[index, "E-X(kJ/mol)"] = data["Atom formation enthalpy (kJ/mol)"]
        df_b3.loc[index, "A-X(kJ/mol)"] = data["Electron affinity (kJ/mol)"]
        df_b3.loc[index, "N-X"] = data["Atomic number"]

# %%
for element_a, data_a in bond_energy_A_X.items():
    for element_x, bond_energy in data_a.items():
        mask = (df_b3['A'] == element_a) & (df_b3['X'] == element_x)
        df_b3.loc[mask, 'BE(A-X)'] = bond_energy

# %%
for element_a, data_a in bond_energy_A_X.items():
    for element_x, bond_energy in data_a.items():
        mask = (df_b3['B1'] == element_a) & (df_b3['X'] == element_x)
        df_b3.loc[mask, 'BE(B1-X)'] = bond_energy

# %%
for element_a, data_a in bond_energy_B3_X.items():
    for element_x, bond_energy in data_a.items():
        mask = (df_b3['B3'] == element_a) & (df_b3['X'] == element_x)
        df_b3.loc[mask, 'BE(B3-X)'] = bond_energy

# %%
df_b3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1550 entries, 0 to 1549
# Data columns (total 33 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   formula       1550 non-null   object
#  1   A             1550 non-null   object
#  2   B1            1550 non-null   object
#  3   B3            1550 non-null   object
#  4   X             1550 non-null   object
#  5   R-A(pm)       1550 non-null   float64
#  6   I-A(kJ/mol)   1550 non-null   float64
#  7   V-A           1550 non-null   float64
#  8   P-A           1550 non-null   float64
#  9   E-A(kJ/mol)   1550 non-null   float64
#  10  N-A           1550 non-null   float64
#  11  R-B1(pm)      1550 non-null   float64
#  12  X-B1(kJ/mol)  1550 non-null   float64
#  13  V-B1          1550 non-null   float64
#  14  P-B1          1550 non-null   float64
#  15  E-B1(kJ/mol)  1550 non-null   float64
#  16  N-B1          1550 non-null   float64
# ...

# %%
df_b3.to_csv("/content/drive/MyDrive/Colab-dataset/synthetic_data_b3.csv")
df_b2.to_csv("/content/drive/MyDrive/Colab-dataset/synthetic_data_b2.csv")
